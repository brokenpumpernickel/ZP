# %%
from yolo import hello_world

hello_world()
# Out:
# Hello, World!

# %%
from abc import ABC, abstractmethod
class StepRule(ABC):
    @abstractmethod
    def next_step(self, previous_step, simulations_parameters):
        pass

class Visualizer(ABC):
    @abstractmethod
    def visualize(self, steps):
        pass

class OscillatorRule(StepRule):
    def next_step(self, previous_step, simulations_parameters):
        next_state = SimulationState()
        next_state.x = previous_step.x + previous_step.v * simulations_parameters.step_size
        next_state.v = previous_step.v
        return next_state

# %%
class Simulation:
    def __init__(self, simulations_parameters, step_rule: StepRule):
        self.simulations_parameters = simulations_parameters
        self.step_rule = step_rule

    def run(self, initial_step, num_steps):
        steps = [initial_step]
        for _ in range(num_steps):
            next_step = self.step_rule.next_step(steps[-1], self.simulations_parameters)
            steps.append(next_step)
        return steps
